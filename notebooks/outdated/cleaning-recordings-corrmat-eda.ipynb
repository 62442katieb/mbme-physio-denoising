# %%
import numpy as np
import pandas as pd
import seaborn as sns
import bioread as br
import dtw

import matplotlib.pyplot as plt
import scipy.signal as signal
import sklearn
import os
from sklearn.metrics import normalized_mutual_info_score, pairwise_distances
from scipy.stats import spearmanr

# %%
print('bioread, v.', br.__version__)
print('numpy, v.', np.__version__)
print('dtw, v.', dtw.__version__)
print('sklearn, v.', sklearn.__version__)
# Out:
# bioread, v. 1.0.4
# numpy, v. 1.19.0
# dtw, v. 1.4.0
# sklearn, v. 0.23.1

# %%
#sns.crayons

# %%
sns.set_context('paper')

pal = sns.crayon_palette(['Outrageous Orange', 'Red Orange', 'Orange', 'Yellow Orange', 'Burnt Orange'])
sns.set_palette(pal)
sns.palplot(pal)

# %%
pd.options.mode.chained_assignment = None

def consecutive(data, stepsize=0.000501):
    return np.split(data, np.where(np.diff(data) != stepsize)[0]+1)

def butter_highpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = signal.butter(order, normal_cutoff, btype='high', analog=False)
    return b, a

def butter_highpass_filter(data, cutoff, fs, order=5):
    b, a = butter_highpass(cutoff, fs, order=order)
    y = signal.filtfilt(b, a, data)
    return y

def comb_band_stop(notch, filtered, Q, fs):
    max_harmonic = int(nyquist/notch)
    min_harmonic = 1
    for i in np.arange(1, max_harmonic):
        #print(notch * i)
        f0 = notch * i
        w0 = f0/nyquist
        b,a = signal.iirnotch(w0, Q)
        filtered = signal.filtfilt(b, a, filtered)
    j = 1
    while (notch / j) > 1:
        #print(notch * i)
        f0 = notch / i
        w0 = f0/nyquist
        b,a = signal.iirnotch(w0, Q)
        filtered = signal.filtfilt(b, a, filtered)
        j += 1
    return filtered

# %%
data_fname = '/Users/kbottenh/Dropbox/Projects/physio/mbme-physio-denoising/example_data/sub-Blossom_ses-01.acq'
data = br.read_file(data_fname)
basename = data_fname.split('/')[-1][:-4]
out_dir = '/Users/kbottenh/Dropbox/Projects/physio/physio-note'

if not os.path.exists('{0}/data'.format(out_dir)):
    os.mkdir('{0}/data'.format(out_dir))
    os.mkdir('{0}/data/clean'.format(out_dir))
    os.mkdir('{0}/data/raw'.format(out_dir))
    os.mkdir('{0}/figures'.format(out_dir))
    
for channel in data.named_channels:
    #print(channel)
    if 'ECG' in channel:
        ecg_channel = channel
    #elif 'Digital' in channel:
    elif 'Trigger' in channel:
        trigger = channel
    elif 'EDA' in channel:
        eda_channel = channel
    elif 'Respiration' in channel:
        resp_channel = channel

timeseries = pd.DataFrame(columns=['ECG', 'EDA', 'Trigger', 'Resp', 'seconds'])

timeseries['Trigger'] = data.named_channels[trigger].data
#timeseries['ECG'] = data.named_channels[ecg_channel].data
timeseries['EDA'] = data.named_channels[eda_channel].data
#timeseries['Resp'] = data.named_channels[resp_channel].data
timeseries['seconds'] = data.time_index
timeseries.to_csv('{0}/data/raw/{1}-raw.csv'.format(out_dir, basename))

#separating timeseries collected during BOLD scan
#(where trigger channel = 5V)
fives = timeseries[timeseries['Trigger'] == 5].index.values
scan_idx = consecutive(fives, stepsize=1)

#from DIVA
slices = 48
tr = 1.5
mb = 3

#slices = 60
#tr = 0.8
#mb = 6
cutoff = 120

fs = data.samples_per_second

nyquist = fs/2
Q = 100

# %%
fft_ecg_nomri = signal.decimate(np.fft.fft(timeseries[timeseries['Trigger'] != 5]['EDA'][:1000000]), 10)
freq_ecg_nomri = signal.decimate(np.fft.fftfreq(timeseries[timeseries['Trigger'] != 5]['EDA'][:1000000].shape[-1], d=0.0005), 10)

limit = np.where(freq_ecg_nomri >= 10)[0][0]

# %%
scans = {}
for i in range(len(scan_idx)):
    duration = len(scan_idx[i])/2000./60
    #print(i, np.round(duration, 1), 'minutes')
    if duration > 2.:
        scans[i] = duration
print(scans)
# Out:
# {0: 9.394791666666666, 1: 7.744491666666667, 2: 7.7928, 3: 7.350816666666666, 4: 7.976075, 5: 10.925783333333333, 6: 7.412583333333333, 7: 7.43005, 8: 5.836325, 9: 8.253416666666666, 10: 5.0017249999999995, 11: 5.001608333333333}

# %%
fft_ecg = {}
freq = {}
ecg = {}
for scan in scans.keys():
    ecg[scan] = timeseries[timeseries.index.isin(scan_idx[scan])]['EDA']
    fft_ecg[scan] = signal.decimate(np.fft.fft(ecg[scan]), 10)
    freq[scan] = signal.decimate(np.fft.fftfreq(ecg[scan].shape[-1], d=0.0005), 10)
    limit = np.where(freq[scan].real >= 0.5)[0][0]
    sns.lineplot(freq[scan][:limit], fft_ecg[scan].real[:limit])

# %%
np.where(freq[scan].real >= 0.5)[0][0]
# Out:
# 16

# %%
steps_in_denoising = ['raw', 'BIOPAC', 'MB-BIOPAC', 'Bottenhorn']

# %%
index = pd.MultiIndex.from_product([scans.keys(), steps_in_denoising], names=['scan', 'step'])

# %%
#msc = {}
dist = pd.DataFrame(index=index, columns=index, dtype=float)
for scan1 in scans.keys():
    fft1 = fft_ecg[scan1].real
    corr = np.corrcoef(abs(fft1[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
    dist.at[(scan1, 'raw'), 'noMR'] = corr
    
    notch = slices / tr
    filtered = comb_band_stop(notch, ecg[scan1], Q, fs)
    fft_bpfilt1 = signal.decimate(np.fft.fft(filtered),10)
    corr = np.corrcoef(abs(fft_bpfilt1[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
    dist.at[(scan1, 'BIOPAC'), 'noMR'] = corr
    
    corr = np.corrcoef(abs(fft1[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
    dist.at[(scan1, 'raw'), (scan1, 'BIOPAC')] = corr
    dist.at[(scan1, 'BIOPAC'), (scan1, 'raw')] = corr
    
    notch = slices / mb / tr
    filtered = comb_band_stop(notch, ecg[scan1], Q, fs)
    fft_bpmbfilt1 = signal.decimate(np.fft.fft(filtered), 10)
    corr = np.corrcoef(abs(fft_bpmbfilt1[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
    dist.at[(scan1, 'MB-BIOPAC'), 'noMR'] = corr
    corr = np.corrcoef(abs(fft1[:limit]), abs(fft_bpmbfilt1[:limit]))[0][1]
    dist.at[(scan1, 'raw'), (scan1, 'MB-BIOPAC')] = corr
    dist.at[(scan1, 'MB-BIOPAC'), (scan1, 'raw')] = corr
    corr = np.corrcoef(abs(fft_bpmbfilt1[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
    dist.at[(scan1, 'BIOPAC'), (scan1, 'MB-BIOPAC')] = corr
    dist.at[(scan1, 'MB-BIOPAC'), (scan1, 'BIOPAC')] = corr
    
    notches = {'slices': slices / mb / tr, 
               'tr': 1 / tr}
    filtered1 = ecg[scan1]
    for notch in notches:
        filtered1 = comb_band_stop(notches[notch], filtered1, Q, fs)
    
    fft_bottfilt1 = signal.decimate(np.fft.fft(filtered1), 10)
    corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
    dist.at[(scan1, 'Bottenhorn'), 'noMR'] = corr
    corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
    dist.at[(scan1, 'Bottenhorn'), 'noMR'] = corr
    
    corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft1[:limit]))[0][1]
    dist.at[(scan1, 'raw'), (scan1, 'Bottenhorn')] = corr
    dist.at[(scan1, 'Bottenhorn'), (scan1, 'raw')] = corr
    corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
    dist.at[(scan1, 'BIOPAC'), (scan1, 'Bottenhorn')] = corr
    dist.at[(scan1, 'Bottenhorn'), (scan1, 'BIOPAC')] = corr
    corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_bpmbfilt1[:limit]))[0][1]
    dist.at[(scan1, 'MB-BIOPAC'), (scan1, 'Bottenhorn')] = corr
    dist.at[(scan1, 'Bottenhorn'), (scan1, 'MB-BIOPAC')] = corr

    for scan2 in scans.keys():
        fft2 = fft_ecg[scan2].real
        corr =  np.corrcoef(abs(fft1[:limit]), abs(fft2[:limit]))[0][1]
        dist.at[(scan2, 'raw'), (scan1, 'raw')] = corr
        dist.at[(scan1, 'raw'), (scan2, 'raw')] = corr
        corr = np.corrcoef(abs(fft2[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
        dist.at[(scan2, 'raw'), 'noMR'] = corr
        corr = np.corrcoef(abs(fft2[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
        dist.at[(scan2, 'raw'), (scan1, 'BIOPAC')] = corr
        corr = np.corrcoef(abs(fft2[:limit]), abs(fft_bpmbfilt1[:limit]))[0][1]
        dist.at[(scan2, 'raw'), (scan1, 'MB-BIOPAC')] = corr
        corr = np.corrcoef(abs(fft2[:limit]), abs(fft_bottfilt1[:limit]))[0][1]
        dist.at[(scan2, 'raw'), (scan1, 'Bottenhorn')] = corr

        notch = slices / tr
        filtered = comb_band_stop(notch, ecg[scan2], Q, fs)
        fft_bpfilt2 = signal.decimate(np.fft.fft(filtered),10)
        corr = np.corrcoef(abs(fft_bpfilt2[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), 'noMR'] = corr
        corr = np.corrcoef(abs(fft1[:limit]), abs(fft_bpfilt2[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), (scan1, 'raw')] = corr
        corr = np.corrcoef(abs(fft_bpfilt2[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), (scan1, 'BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bpmbfilt1[:limit]), abs(fft_bpfilt2[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), (scan1, 'MB-BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_bpfilt2[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), (scan1, 'Bottenhorn')] = corr
        #corr = np.corrcoef(abs(fft1[:limit]), abs(fft_bpfilt2[:limit]))[0][1]
        #dist.at[(scan2, 'BIOPAC'), (scan1, 'raw')] = corr

        notch = slices / mb / tr
        filtered = comb_band_stop(notch, ecg[scan2], Q, fs)
        fft_bpmbfilt2 = signal.decimate(np.fft.fft(filtered), 10)
        corr = np.corrcoef(abs(fft_bpmbfilt2[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), 'noMR'] = corr
        corr = np.corrcoef(abs(fft_bpmbfilt2[:limit]), abs(fft1[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), (scan1, 'raw')] = corr
        corr = np.corrcoef(abs(fft_bpmbfilt2[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), (scan1, 'BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bpmbfilt1[:limit]), abs(fft_bpmbfilt2[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), (scan1, 'MB-BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_bpmbfilt2[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), (scan1, 'Bottenhorn')] = corr
        
        filtered1 = ecg[scan2]
        for notch in notches:
            filtered1 = comb_band_stop(notches[notch], filtered1, Q, fs)

        fft_bottfilt2 = signal.decimate(np.fft.fft(filtered1),10)
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_ecg_nomri[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), 'noMR'] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), (scan1, 'BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft1[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), (scan1, 'raw')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpmbfilt1[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), (scan1, 'MB-BIOPAC')] = corr
        corr = np.corrcoef(abs(fft_bottfilt1[:limit]), abs(fft_bottfilt2[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), (scan1, 'Bottenhorn')] = corr

        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft2[:limit]))[0][1]
        dist.at[(scan2, 'raw'), (scan2, 'Bottenhorn')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft1[:limit]))[0][1]
        dist.at[(scan2, 'Bottenhorn'), (scan1, 'raw')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpfilt2[:limit]))[0][1]
        dist.at[(scan2, 'BIOPAC'), (scan2, 'Bottenhorn')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpmbfilt2[:limit]))[0][1]
        dist.at[(scan2, 'MB-BIOPAC'), (scan2, 'Bottenhorn')] = corr
        
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft1[:limit]))[0][1]
        dist.at[(scan1, 'raw'), (scan2, 'Bottenhorn')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpfilt1[:limit]))[0][1]
        dist.at[(scan1, 'BIOPAC'), (scan2, 'Bottenhorn')] = corr
        corr = np.corrcoef(abs(fft_bottfilt2[:limit]), abs(fft_bpmbfilt1[:limit]))[0][1]
        dist.at[(scan1, 'MB-BIOPAC'), (scan2, 'Bottenhorn')] = corr

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(dist, square=True, cmap='viridis', )
fig.savefig(os.path.join(out_dir, 'figures', 'fft_correlations-{0}.png'.format(basename)), dpi=300)

# %%
dist.sort_values('noMR', axis=0, ascending=False)
# Out:
# scan                    0                                        1            \
# step                  raw    BIOPAC MB-BIOPAC Bottenhorn       raw    BIOPAC
# scan step
# 0    raw         1.000000  0.999996  0.999996   0.999996  0.999996  0.999996
# 6    raw         0.999999  0.999996  0.999996   0.999996  0.999995  0.999995
# 11   raw         0.999999  0.999997  0.999997   0.999997  0.999998  0.999998
#      BIOPAC      0.999999  0.999997  0.999997   0.999997  0.999998  0.999998
#      MB-BIOPAC   0.999999  0.999997  0.999997   0.999997  0.999999  0.999998
#      Bottenhorn  0.999999  0.999997  0.999997   0.999997  0.999999  0.999998
# 2    raw         0.999996  0.999990  0.999990   0.999990  0.999987  0.999986
# 4    raw         0.999998  0.999998  0.999998   0.999998  0.999999  0.999999
# 2    Bottenhorn  0.999997  0.999993  0.999993   0.999993  0.999989  0.999989
#      MB-BIOPAC   0.999997  0.999993  0.999993   0.999993  0.999989  0.999989
# 4    BIOPAC      0.999998  0.999998  0.999998   0.999998  0.999999  0.999999
#      MB-BIOPAC   0.999998  0.999998  0.999998   0.999998  0.999999  0.999999
#      Bottenhorn  0.999998  0.999998  0.999998   0.999998  0.999999  0.999999
# 2    BIOPAC      0.999997  0.999993  0.999993   0.999993  0.999989  0.999989
# 6    MB-BIOPAC   0.999998  0.999999  0.999999   0.999999  0.999997  0.999997
#      Bottenhorn  0.999998  0.999999  0.999999   0.999999  0.999997  0.999997
#      BIOPAC      0.999998  0.999999  0.999999   0.999999  0.999997  0.999997
# 10   raw         0.999997  0.999999  0.999999   0.999999  1.000000  1.000000
# 5    raw         0.999996  0.999997  0.999997   0.999997  0.999997  0.999997
# 10   MB-BIOPAC   0.999997  0.999999  0.999999   0.999999  1.000000  1.000000
#      Bottenhorn  0.999997  0.999999  0.999999   0.999999  1.000000  1.000000
#      BIOPAC      0.999997  0.999999  0.999999   0.999999  1.000000  1.000000
# 8    MB-BIOPAC   0.999973  0.999974  0.999974   0.999974  0.999964  0.999964
#      Bottenhorn  0.999973  0.999974  0.999974   0.999974  0.999964  0.999964
#      BIOPAC      0.999973  0.999974  0.999974   0.999974  0.999964  0.999964
# 3    MB-BIOPAC   0.999973  0.999973  0.999973   0.999973  0.999966  0.999966
#      Bottenhorn  0.999973  0.999973  0.999973   0.999973  0.999966  0.999966
#      BIOPAC      0.999972  0.999973  0.999973   0.999973  0.999965  0.999965
#
# scan                                      noMR
# step            MB-BIOPAC Bottenhorn
# scan step
# 0    raw         0.999999   0.999999  0.999997
# 6    raw         0.999997   0.999997  0.999996
# 11   raw         1.000000   1.000000  0.999995
#      BIOPAC      1.000000   1.000000  0.999995
#      MB-BIOPAC   1.000000   1.000000  0.999995
#      Bottenhorn  1.000000   1.000000  0.999995
# 2    raw         0.999992   0.999992  0.999994
# 4    raw         1.000000   1.000000  0.999994
# 2    Bottenhorn  0.999993   0.999993  0.999994
#      MB-BIOPAC   0.999993   0.999993  0.999994
# 4    BIOPAC      1.000000   1.000000  0.999994
#      MB-BIOPAC   1.000000   1.000000  0.999994
#      Bottenhorn  1.000000   1.000000  0.999994
# 2    BIOPAC      0.999993   0.999993  0.999994
# 6    MB-BIOPAC   0.999997   0.999997  0.999991
#      Bottenhorn  0.999997   0.999997  0.999991
#      BIOPAC      0.999997   0.999997  0.999991
# 10   raw         0.999999   0.999999  0.999991
# 5    raw         0.999996   0.999996  0.999991
# 10   MB-BIOPAC   0.999999   0.999999  0.999991
#      Bottenhorn  0.999999   0.999999  0.999991
#      BIOPAC      0.999999   0.999999  0.999991
# 1    raw         0.999999   0.999999  0.999990
#      Bottenhorn  0.999998   0.999998  0.999989
#      MB-BIOPAC   0.999998   0.999998  0.999989
#      BIOPAC      0.999998   0.999998  0.999989
# 7    raw         0.999997   0.999997  0.999989
# 0    BIOPAC      0.999997   0.999997  0.999988
#      MB-BIOPAC   0.999997   0.999997  0.999988
#      Bottenhorn  0.999997   0.999997  0.999988
# 7    BIOPAC      0.999996   0.999996  0.999987
#      MB-BIOPAC   0.999996   0.999996  0.999987
#      Bottenhorn  0.999996   0.999996  0.999987
# 9    raw         0.999997   0.999997  0.999987
#      MB-BIOPAC   0.999997   0.999997  0.999986
#      Bottenhorn  0.999997   0.999997  0.999986
#      BIOPAC      0.999997   0.999997  0.999986
# 5    BIOPAC      0.999990   0.999990  0.999977
#      Bottenhorn  0.999990   0.999990  0.999977
#      MB-BIOPAC   0.999990   0.999990  0.999977
# 8    raw         0.999982   0.999982  0.999966
# 3    raw         0.999970   0.999970  0.999946
# 8    MB-BIOPAC   0.999964   0.999964  0.999940
#      Bottenhorn  0.999964   0.999964  0.999940
#      BIOPAC      0.999964   0.999964  0.999940
# 3    MB-BIOPAC   0.999966   0.999966  0.999939
#      Bottenhorn  0.999966   0.999966  0.999939
#      BIOPAC      0.999965   0.999965  0.999939
#
# [48 rows x 49 columns]

# %%
dist.to_csv(os.path.join(out_dir, 'fft_correlations-EDA-{0}.csv'.format(basename)))
